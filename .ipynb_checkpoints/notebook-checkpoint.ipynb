# %% [markdown]
# # 📊 **Analisis Data Penjualan pada Dataset E-Commerce Publik | SUBMISSION COURSE**
#
# ---
#
# ### 👤 **Nama** : **Andhika Septian Prayoga**
# ### 📧 **Email** : [andhika.elite007@gmail.com](mailto:andhika.elite007@gmail.com) | [mc299d5y1775@student.devacademy.id](mailto:mc299d5y1775@student.devacademy.id)
# ### 🆔 **ID** : **MC299D5Y1775**
#
# ---

# %% [markdown]
# Berikut merupakan fokus utama dari analisis data penjualan pada platform E-Commerce:
#
# ---
#
# 1. 📦 **Apa saja produk terlaris dan produk yang kurang diminati dalam beberapa bulan terakhir?**
#    *→ Untuk mengidentifikasi tren penjualan dan optimalisasi stok produk.*
#
# 2. 💸 **Berapa banyak total pengeluaran pelanggan selama periode tertentu?**
#    *→ Untuk memahami perilaku belanja pelanggan dan potensi pendapatan.*
#
# 3. 📈 **Bagaimana perkembangan performa penjualan dari waktu ke waktu?**
#    *→ Untuk mengevaluasi tren pertumbuhan atau penurunan penjualan.*
#
# 4. 🌍 **Dimana lokasi geografis pelanggan terbanyak berada?**
#    *→ Untuk mendukung strategi pemasaran dan distribusi produk.*
#
# ---

# %% [markdown]
# #  **Requirement Library yang di butuhkan**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib
# !pip install unidecode
import unidecode
import matplotlib.image as mpimg

# %% [markdown]
# ### Data Wrangling
# #### Pengumpulan Dataset

# %%
# Mendapatkan semua dataset yang diperlukan
customers_df = pd.read_csv('data/customers_dataset.csv')
geo_df = pd.read_csv('data/geolocation_dataset.csv')
order_items_df = pd.read_csv('data/order_items_dataset.csv')
order_pay = pd.read_csv('data/order_payments_dataset.csv')
order_rev = pd.read_csv('data/order_reviews_dataset.csv')
orders_df = pd.read_csv('data/orders_dataset.csv')
product_cat = pd.read_csv('data/product_category_name_translation.csv')
products_df = pd.read_csv('data/products_dataset.csv')
sellers_df = pd.read_csv('data/sellers_dataset.csv')

# tampilan beberapa baris pertama dari setiap dataset
print("Customers DataFrame:")
print(customers_df.head())

print("\nGeolocation DataFrame:")
print(geo_df.head())

print("\nOrder Items DataFrame:")
print(order_items_df.head())

print("\nOrder Payments DataFrame:")
print(order_pay.head())

print("\nOrder Reviews DataFrame:")
print(order_rev.head())

print("\nOrders DataFrame:")
print(orders_df.head())

print("\nProduct Category Translation DataFrame:")
print(product_cat.head())

print("\nProducts DataFrame:")
print(products_df.head())

print("\nSellers DataFrame:")
print(sellers_df.head())
# Out:
# Customers DataFrame:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
# Geolocation DataFrame:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# ...

# %% [markdown]
# ### Assessing Data
# #### Penilaian Pengecekan Data

# %%
print('\n', customers_df.info())
print('\n', geo_df.info())
print('\n', order_items_df.info())
print('\n', order_pay.info())
print('\n', order_rev.info())
print('\n', orders_df.info())
print('\n', product_cat.info())
print('\n', products_df.info())
print('\n', sellers_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
# ...

# %%
print('\nInfo data null customers:\n', customers_df.isnull().sum())
print('\nInfo data null geolocation:\n', geo_df.isnull().sum())
print('\nInfo data null order items:\n', order_items_df.isnull().sum())
print('\nInfo data null order payments:\n', order_pay.isnull().sum())
print('\nInfo data null order reviews:\n', order_rev.isnull().sum())
print('\nInfo data null orders:\n', orders_df.isnull().sum())
print('\nInfo data null product category:\n', product_cat.isnull().sum())
print('\nInfo data null products:\n', products_df.isnull().sum())
print('\nInfo data null sellers:\n', sellers_df.isnull().sum())
# Out:
# Info data null customers:
#  customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Info data null geolocation:
#  geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64
#
# Info data null order items:
#  order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# Info data null order payments:
#  order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64
#
# Info data null order reviews:
#  review_id                      0
# order_id                       0
# review_score                   0
# ...

# %%
print('Info data duplikat customers:', customers_df.duplicated().sum())
print('Info data duplikat geolocation:', geo_df.duplicated().sum())
print('Info data duplikat order items:', order_items_df.duplicated().sum())
print('Info data duplikat order payments:', order_pay.duplicated().sum())
print('Info data duplikat order reviews:', order_rev.duplicated().sum())
print('Info data duplikat orders:', orders_df.duplicated().sum())
print('Info data duplikat product category:', product_cat.duplicated().sum())
print('Info data duplikat products:', products_df.duplicated().sum())
print('Info data duplikat sellers:', sellers_df.duplicated().sum())
# Out:
# Info data duplikat customers: 0
# Info data duplikat geolocation: 261831
# Info data duplikat order items: 0
# Info data duplikat order payments: 0
# Info data duplikat order reviews: 0
# Info data duplikat orders: 0
# Info data duplikat product category: 0
# Info data duplikat products: 0
# Info data duplikat sellers: 0

# %%
print('\nData describe customers:\n', customers_df.describe(include='all'))
print('\nData describe geolocation:\n', geo_df.describe(include='all'))
print('\nData describe order items:\n', order_items_df.describe(include='all'))
print('\nData describe order payments:\n', order_pay.describe(include='all'))
print('\nData describe order reviews:\n', order_rev.describe(include='all'))
print('\nData describe orders:\n', orders_df.describe(include='all'))
print('\nData describe product category:\n', product_cat.describe(include='all'))
print('\nData describe products:\n', products_df.describe(include='all'))
print('\nData describe sellers:\n', sellers_df.describe(include='all'))
# Out:
# Data describe customers:
#                               customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
# ...

# %%
geo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# ### Cleaning Data
# #### Setelah pengecekan data, ditemukan duplikat pada Geolocation dataset. Oleh karena itu, drop duplikat tidak dilakukan. Kolom *'geolocation_city', 'geolocation_state'* dengan nilai tertinggi adalah **sao paulo (SP)**

# %%
order_rev[order_rev.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
order_rev.review_comment_title.value_counts()
# Out:
# review_comment_title
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: count, Length: 4527, dtype: int64

# %%
order_rev[order_rev.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title review_comment_message  \
# ...

# %%
order_rev.review_comment_message.value_counts()
# Out:
# review_comment_message
# Muito bom                                                                                                                                                                                              230
# Bom                                                                                                                                                                                                    189
# muito bom                                                                                                                                                                                              122
# bom                                                                                                                                                                                                    107
# ...

# %%
order_rev.fillna(value="no comment", inplace=True)

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
datetime_oi = ["shipping_limit_date"]

for column in datetime_oi:
    order_items_df[column] = pd.to_datetime(order_items_df[column])

# %%
datetime_or = ["review_creation_date","review_answer_timestamp"]

for column in datetime_or:
  order_rev[column] = pd.to_datetime(order_rev[column])

# %%
datetime_oo = ["order_purchase_timestamp","order_approved_at","order_delivered_carrier_date","order_delivered_customer_date","order_estimated_delivery_date"]

for column in datetime_oo:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# ### Exploratory Data
# #### Analisis data eksploratif dilakukan untuk memahami distribusi data, mengidentifikasi pola, dan menemukan wawasan awal yang dapat membantu dalam analisis lebih lanjut.

# %%
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 55704  c19fd1f70eda21df900b350e67c26ffe  43609bac99eff5f455f5ed4ac1f78171
# 67844  72ec1bb6ed4621056c6774c4c385640b  864adb6f60fff0c2a11613045507d350
# 24043  4dfeeaf74cd7936d013802d1cc2e0c0a  00370dfde3d012c420d29657afc2fc8b
# 61683  40a0950f8eea6c18a2d6a8587c195253  a61f3d42fe066b53106cec5ad80499d3
# 47726  ee46c93e6151b7c853a1fd784065695f  2fb6dae4fb3a2f917940978144362cd2
#
#        customer_zip_code_prefix  customer_city customer_state
# 55704                     75650      morrinhos             GO
# 67844                     70610       brasilia             DF
# 24043                     96930     candelaria             RS
# 61683                     95058  caxias do sul             RS
# 47726                     84900         ibaiti             PR

# %%
customers_df.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.customer_id.is_unique
# Out:
# True

# %%
customers_df.customer_id.duplicated
# Out:
# <bound method Series.duplicated of 0        06b8999e2fba1a1fbc88172c00ba8bc7
# 1        18955e83d337fd6b2def6b18a428ac77
# 2        4e7b3e00288586ebd08712fdd0374a03
# 3        b2b6027bc5c5109e529d4dc6358b12c3
# 4        4f2d8ab171c80ec8364f7c12e35b23ad
#                        ...
# 99436    17ddf5dd5d51696bb3d7c6291687be6f
# 99437    e7b71a9017aa05c9a7fd292d714858e8
# 99438    5e28dfe12db7fb50a4b2f691faecea5e
# 99439    56b18e2166679b8a959d72dd06da27f9
# 99440    274fa6071e5e17fe303b9748641082c8
# Name: customer_id, Length: 99441, dtype: object>

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %%
order_pay.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 25311  318160e821f4c754080f46f95afc1ded                   1       boleto
# 930    b0e1d9af1bfc3a4d96489c81cf10fe69                   1  credit_card
# 39702  6b8c07c310d8c6a39e79ed3d38e6578f                   1  credit_card
# 98966  8875c81503e02bc22eae5a31637d6db1                   1  credit_card
# 31323  bdcf9c2f3ef0c55dc1273dd2c507b0f8                   1  credit_card
#
#        payment_installments  payment_value
# 25311                     1          56.92
# 930                       1         135.60
# 39702                     8         647.54
# 98966                     4         188.43
# 31323                     1          61.83

# %%
order_pay.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
order_pay.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 69330  500c54b4910a5312b3afc7ab377b1a98  22d36fcccd3acff33874992a456a2d39
# 94307  2c0e4f78d8fdd3b6921776078f2c8080  0558be6a6e500f5cf3ab336365099074
# 22473  8616d2e4f9d29d0a08571be7ccf0acc3  7add403a697858f1a47857c3e396b54d
# 74053  f23565614af219662cb662c56a0d2f71  db2539853e0c422a7bf64e43bafe390f
# 26361  c1efc16c61c46cc2eff17d0ea6202aaf  5c990f280a0c04e9d265be77a09a5be8
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 69330    delivered      2018-03-02 13:34:44 2018-03-02 13:55:13
# 94307    delivered      2018-06-11 18:47:39 2018-06-11 19:19:39
# 22473    delivered      2018-05-08 00:14:57 2018-05-10 02:57:15
# 74053    delivered      2017-10-07 19:33:57 2017-10-07 19:49:57
# 26361    delivered      2017-11-14 15:27:02 2017-11-14 15:35:36
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 69330          2018-03-06 00:08:53           2018-03-17 15:03:39
# ...

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_delivered_carrier_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 50910  01d95eed9163a292a6788ddac08bcf31  8a0d726f209fe6181dfe3d5a64d75450
# 98516  577b745a85120419fe27073e3c9e1a76  dc5e8db48a49602f506e67b843668d72
# 42877  75674608f3fd582a5d47385912f8aaf2  98999b0297379e3d3546368b6b8910fc
# 54376  b5839f6ef0df11dd4912bc5bfa299e3f  8af9ca2cbcc90d6735f67957915853f9
# 35523  907f97a18c02082128c530919e8fe089  d65b5eb4db1dc746ce03098d3eee419c
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 50910    delivered      2017-11-08 09:54:42 2017-11-09 04:31:05
# 98516    delivered      2018-04-26 21:57:27 2018-04-27 13:30:54
# 42877    delivered      2018-03-10 22:53:51 2018-03-10 23:08:07
# 54376    delivered      2017-12-01 11:02:53 2017-12-01 11:31:01
# 35523    delivered      2017-08-07 21:11:12 2017-08-07 22:04:14
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 50910          2017-11-14 11:29:03           2017-12-05 00:26:03
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(orders_df['delivery_time'], bins=30, kde=True)
plt.title('Distribusi Waktu Pengiriman')
plt.xlabel('Waktu Pengiriman (hari)')
plt.ylabel('Frekuensi')
plt.axvline(orders_df['delivery_time'].mean(), color='r', linestyle='--', label=f'Mean: {orders_df["delivery_time"].mean():.2f} hari')
plt.legend()
plt.show()

# %%
customer_id_in_orders_df = orders_df.customer_id.values

customers_df["status"] = customers_df["customer_id"].isin(customer_id_in_orders_df).map({True: "Active", False: "Non Active"})

customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 86408  12ffbbab2039d22b5c5bd4de2b0ffc78  39dd57f5a7f80ad335912eee5f7f0fb6
# 63475  26cf824d990f4e2e89a215ab62b61873  c51fab090c0c77556a1a762add555fef
# 14793  a1519634d0ae8ab534c5ff9a1ba53c89  26e28dec8cb5276d208656aa1c8b3b50
# 9837   eb6fe4f7dfa98e8ff658e2655a0e4815  240f601d04eca6821d5b4d9f9a7dc477
# 95417  fcd47b43cac861c981572131ac384b4d  62b51994b2d741607f9f24775a92a355
#
#        customer_zip_code_prefix customer_city customer_state  status
# 86408                     37910  delfinopolis             MG  Active
# 63475                     76821   porto velho             RO  Active
# 14793                     79550    costa rica             MS  Active
# 9837                      99070   passo fundo             RS  Active
# 95417                      8552           poa             SP  Active

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active    99441
# Name: customer_id, dtype: int64

# %%
cust_orders_df = pd.merge(
    left=customers_df,
    right=orders_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
cust_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
cust_orders_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: order_id, dtype: int64

# %%
cust_orders_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: order_id, dtype: int64

# %%
cust_orders_df.groupby(by="customer_zip_code_prefix").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_zip_code_prefix
# 22790    142
# 24220    124
# 22793    121
# 24230    117
# 22775    110
# 29101    101
# 13212     95
# 35162     93
# 22631     89
# 38400     87
# Name: order_id, dtype: int64

# %%
cust_orders_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_id, dtype: int64

# %%
order_payrev_df = pd.merge(
    left=order_pay,
    right=order_rev,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
order_payrev_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# ...

# %%
order_payrev_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
order_payrev_df.sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 52415  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34565  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41660  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49871  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 86018  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 78326  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 51581  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 37030  fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 94953  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 20031  8bcbe01d44d147f901cd3192671144db                   4      voucher
#
#        payment_installments  payment_value                         review_id  \
# ...

# %%
order_payrev_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value":  ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %%
customers_df = pd.merge(
    left=cust_orders_df,
    right=order_payrev_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
item_seller_df = pd.merge(
    left=order_items_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
item_seller_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
product_df = pd.merge(
    left=products_df,
    right=product_cat,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %%
product_df.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %%
ellers_df = pd.merge(
    left=product_df,
    right=item_seller_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
ellers_df.sort_values(by="price", ascending=False)
# Out:
#                              product_id              product_category_name  \
# 20528  489ae2aa008f021502940f251d4cce7f              utilidades_domesticas
# 73922  69c590f7ffc7bf8db97190b6cb6ed62e                                pcs
# 49503  1bdf5e6731585cf01aa8169c7028d6ad                              artes
# 71835  a6492cc69376c469ab6f61d8f44de961                    eletroportateis
# 32232  c3ed642d592594bb648ff4a04cee2747                    eletroportateis
# ...                                 ...                                ...
# 55911  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55903  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 29610  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29608  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29609  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
#
# ...

# %%
ellers_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price":  ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %%
geo_df.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 960417                        94190       -29.949616       -50.977071
# 480982                        24890       -22.741672       -42.727350
# 908733                        88260       -27.416220       -48.951894
# 785581                        71675       -15.820137       -47.802942
# 388780                        18304       -24.010993       -48.336646
#
#        geolocation_city geolocation_state
# 960417         gravatai                RS
# 480982           tangua                RJ
# 908733    major gercino                SC
# 785581         brasilia                DF
# 388780     capão bonito                SP

# %%
def pretty_string(column):
    column_space = ' '.join(column.split())
    return unidecode.unidecode(column_space.lower())

# %%
geo_df['geolocation_city'] = geo_df['geolocation_city'].apply(pretty_string)

# %%
geo_df.groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 20056       1
# 76370       1
# 63012       1
# 76372       1
# 32635       1
# Length: 19015, dtype: int64

# %%
geo_df[geo_df['geolocation_zip_code_prefix'] == 24220].head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 470805                        24220       -22.905817       -43.106989
# 470811                        24220       -22.902306       -43.112545
# 470812                        24220       -22.904567       -43.110491
# 470820                        24220       -22.902575       -43.109192
# 470821                        24220       -22.907500       -43.106170
#
#        geolocation_city geolocation_state
# 470805          niteroi                RJ
# 470811          niteroi                RJ
# 470812          niteroi                RJ
# 470820          niteroi                RJ
# 470821          niteroi                RJ

# %% [markdown]
# ### Merge ALL DATA
# #### Penggabungan seluruh dataset

# %%
all_data = pd.merge(
    left=customers_df,
    right=ellers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_data.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 42 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    119143 non-null  object
#  1   customer_unique_id             119143 non-null  object
#  2   customer_zip_code_prefix       119143 non-null  int64
#  3   customer_city                  119143 non-null  object
#  4   customer_state                 119143 non-null  object
#  5   status                         119143 non-null  object
#  6   order_id                       119143 non-null  object
#  7   order_status                   119143 non-null  object
#  8   order_purchase_timestamp       119143 non-null  datetime64[ns]
#  9   order_approved_at              118966 non-null  datetime64[ns]
#  10  order_delivered_carrier_date   117057 non-null  datetime64[ns]
# ...

# %%
all_data.groupby(by=["customer_city", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                     price  freight_value
# customer_city       product_category_name_english
# abadia dos dourados books_general_interest          39.90          18.38
#                     cool_stuff                     199.00          20.63
#                     sports_leisure                 120.00          15.59
# abadiania           small_appliances               949.99          75.53
# abaete              baby                            65.00          17.70
# ...                                                   ...            ...
# ze doca             food_drink                      65.00          38.00
#                     garden_tools                    39.90          26.61
#                     musical_instruments            359.00          49.04
#                     sports_leisure                 149.90          38.60
# zortea              computers_accessories           69.90          20.98
#
# [25199 rows x 2 columns]

# %%
all_data.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                                 price  freight_value
# customer_state product_category_name_english
# AC             auto                            606.97         146.42
#                baby                            697.84         174.13
#                bed_bath_table                  567.70         157.51
#                books_general_interest          633.80         123.71
#                christmas_supplies               69.90          60.95
# ...                                               ...            ...
# TO             sports_leisure                 5533.32        1393.53
#                stationery                      276.80          73.80
#                telephony                      1268.12         627.34
#                toys                           1864.15         423.96
#                watches_gifts                  5446.89         950.02
#
# [1356 rows x 2 columns]

# %%
all_data.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 41746     7726078.35
# RJ                 12852     2795615.67
# MG                 11635     2351221.09
# RS                  5466     1160175.66
# PR                  5045     1079795.49
# BA                  3380      805070.98
# SC                  3637      801276.45
# GO                  2020      520481.65
# DF                  2140      438095.32
# ES                  2033      408611.64
# PE                  1652      380294.18
# CE                  1336      349290.36
# PA                   975      263217.70
# MT                   907      257802.26
# MA                   747      200363.24
# PB                   536      181660.73
# MS                   715      167670.27
# PI                   495      137158.89
# RN                   485      117192.91
# AL                   413      112296.47
# SE                   350       90651.44
# TO                   280       72412.08
# ...

# %%
all_data.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         182          1.0  5.0
# air_conditioning                   253          1.0  5.0
# art                                202          1.0  5.0
# arts_and_craftmanship               23          1.0  5.0
# audio                              350          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2311          1.0  5.0
# tablets_printing_image              79          1.0  5.0
# telephony                         4199          1.0  5.0
# toys                              3886          1.0  5.0
# watches_gifts                     5624          1.0  5.0
#
# [71 rows x 3 columns]

# %%
all_data.to_csv('all_data.csv', index=False)

# %% [markdown]
# ## Visualisasi Data
# ### sesuai dengan kebutuhan pertanyaan Bisnis

# %% [markdown]
# 1. **Apa saja produk terlaris dan produk yang kurang diminati dalam beberapa bulan terakhir?**

# %%
# Menggabungkan data products_df dengan product_cat untuk mendapatkan nama kategori dalam bahasa Inggris
products_df = pd.merge(
    left=products_df,
    right=product_cat,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)

# Menggabungkan data order_items_df dengan products_df
order_product_df = pd.merge(
    left=order_items_df,
    right=products_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)

# Menghitung jumlah produk yang terjual
product_sales = order_product_df.groupby('product_category_name_english').size().reset_index(name='sales_count')

# Mengurutkan produk berdasarkan jumlah penjualan
product_sales_sorted = product_sales.sort_values(by='sales_count', ascending=False)

# Menampilkan 10 produk terlaris
top_10_products = product_sales_sorted.head(10)
print("Top 10 Produk Terlaris:")
print(top_10_products)

# Menampilkan 10 produk yang kurang diminati
bottom_10_products = product_sales_sorted.tail(10)
print("\nBottom 10 Produk yang Kurang Diminati:")
print(bottom_10_products)
# Out:
# Top 10 Produk Terlaris:
#    product_category_name_english  sales_count
# 7                 bed_bath_table        11115
# 43                 health_beauty         9670
# 65                sports_leisure         8641
# 39               furniture_decor         8334
# 15         computers_accessories         7827
# 49                    housewares         6964
# 70                 watches_gifts         5991
# 68                     telephony         4545
# 42                  garden_tools         4347
# 5                           auto         4235
#
# Bottom 10 Produk yang Kurang Diminati:
#         product_category_name_english  sales_count
# 41  furniture_mattress_and_upholstery           38
# 55                              music           38
# 35                            flowers           33
# 32                      fashion_sport           30
# 46                     home_comfort_2           30
# 3               arts_and_craftmanship           24
# ...

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Plot Top 10 Produk Terlaris
plt.figure(figsize=(12, 6))
sns.barplot(x='sales_count', y='product_category_name_english', data=top_10_products, palette='viridis')
plt.title('Top 10 Produk Terlaris')
plt.xlabel('Jumlah Penjualan')
plt.ylabel('Kategori Produk')
plt.show()

# Plot Bottom 10 Produk yang Kurang Diminati
plt.figure(figsize=(12, 6))
sns.barplot(x='sales_count', y='product_category_name_english', data=bottom_10_products, palette='magma')
plt.title('Bottom 10 Produk yang Kurang Diminati')
plt.xlabel('Jumlah Penjualan')
plt.ylabel('Kategori Produk')
plt.show()
# Out:
# C:\Users\AndhikaSep\AppData\Local\Temp\ipykernel_22356\2254036062.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sales_count', y='product_category_name_english', data=top_10_products, palette='viridis')
# C:\Users\AndhikaSep\AppData\Local\Temp\ipykernel_22356\2254036062.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sales_count', y='product_category_name_english', data=bottom_10_products, palette='magma')

# %% [markdown]
# ### Produk Terlaris dan Produk yang Kurang Diminati
#
# #### Top 10 Produk Terlaris
# Grafik di bawah ini menunjukkan 10 kategori produk terlaris berdasarkan jumlah penjualan. Kategori produk yang paling diminati adalah `bed_bath_table` dengan jumlah penjualan tertinggi, diikuti oleh `health_beauty`, `sports_leisure`, dan `furniture_decor`. Kategori-kategori ini menunjukkan bahwa pelanggan cenderung membeli produk-produk yang berkaitan dengan kebutuhan rumah tangga, kesehatan, olahraga, dan dekorasi rumah.
#
# #### Bottom 10 Produk yang Kurang Diminati
# Grafik di bawah ini menunjukkan 10 kategori produk yang kurang diminati berdasarkan jumlah penjualan. Kategori produk yang paling sedikit diminati adalah `security_and_services` dengan jumlah penjualan terendah, diikuti oleh `fashion_childrens_clothes`, `cds_dvds_musicals`, dan `la_cuisine`. Kategori-kategori ini menunjukkan bahwa pelanggan cenderung kurang tertarik pada produk-produk yang berkaitan dengan layanan keamanan, pakaian anak-anak, media fisik seperti CD/DVD, dan peralatan dapur khusus.
#
# Dengan memahami produk-produk yang paling diminati dan yang kurang diminati, perusahaan dapat mengoptimalkan strategi pemasaran dan stok produk untuk meningkatkan penjualan dan kepuasan pelanggan.

# %% [markdown]
# 2.**Berapa banyak total pengeluaran pelanggan selama periode tertentu?**

# %%
orders_df['order_purchase_timestamp'] = pd.to_datetime(orders_df['order_purchase_timestamp'])


start_date = '2017-01-01'
end_date = '2018-12-31'


filtered_orders = orders_df[(orders_df['order_purchase_timestamp'] >= start_date) & (orders_df['order_purchase_timestamp'] <= end_date)]


filtered_orders_pay = pd.merge(
    left=filtered_orders,
    right=order_pay,
    how='left',
    left_on='order_id',
    right_on='order_id'
)


total_spending = filtered_orders_pay.groupby('customer_id')['payment_value'].sum().reset_index()


print("Total Pengeluaran Pelanggan selama periode tertentu:")
print(total_spending)
# Out:
# Total Pengeluaran Pelanggan selama periode tertentu:
#                             customer_id  payment_value
# 0      00012a2ce6f8dcda20d059ce98491703         114.74
# 1      000161a058600d5901f007fab4c27140          67.41
# 2      0001fd6190edaaf884bcaf3d49edf079         195.42
# 3      0002414f95344307404f0ace7a26f1d5         179.35
# 4      000379cdec625522490c315e70c7a9fb         107.01
# ...                                 ...            ...
# 99107  fffecc9f79fd8c764f843e9951b11341          81.36
# 99108  fffeda5b6d849fbd39689bb92087f431          63.13
# 99109  ffff42319e9b2d713724ae527742af25         214.13
# 99110  ffffa3172527f765de70084a7e53aae8          45.50
# 99111  ffffe8b65bbe3087b653a978c870db99          18.37
#
# [99112 rows x 2 columns]

# %%
filtered_orders_pay['order_purchase_timestamp'] = pd.to_datetime(filtered_orders_pay['order_purchase_timestamp'])


monthly_spending = filtered_orders_pay.groupby(filtered_orders_pay['order_purchase_timestamp'].dt.to_period('M'))['payment_value'].sum().reset_index()
monthly_spending['order_purchase_timestamp'] = monthly_spending['order_purchase_timestamp'].dt.to_timestamp()


plt.figure(figsize=(14, 7))
sns.lineplot(x='order_purchase_timestamp', y='payment_value', data=monthly_spending, marker='o')
plt.title('Total Pengeluaran Pelanggan per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Total Pengeluaran (Rupiah)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Total Pengeluaran Pelanggan per Bulan
#
# Grafik di bawah ini menunjukkan total pengeluaran pelanggan per bulan selama periode tertentu. Dari grafik ini, kita dapat melihat bagaimana pengeluaran pelanggan berfluktuasi dari bulan ke bulan. Puncak pengeluaran terjadi pada bulan November 2017, yang mungkin disebabkan oleh adanya promosi atau diskon besar-besaran seperti Black Friday. Selain itu, kita juga dapat melihat adanya peningkatan pengeluaran yang signifikan pada awal tahun 2018.
#
# Grafik ini membantu kita memahami tren pengeluaran pelanggan dan dapat digunakan untuk merencanakan strategi pemasaran dan penjualan di masa mendatang.

# %% [markdown]
# 4. **Dimana lokasi geografis pelanggan terbanyak berada?**

# %%
other_state_geolocation = geo_df.groupby(['geolocation_zip_code_prefix'])['geolocation_state'].nunique().reset_index(name='count')
other_state_geolocation[other_state_geolocation['count']>= 2].shape
max_state = geo_df.groupby(['geolocation_zip_code_prefix','geolocation_state']).size().reset_index(name='count').drop_duplicates(subset = 'geolocation_zip_code_prefix').drop('count',axis=1)

# %%
geolocation_silver = geo_df.groupby(['geolocation_zip_code_prefix','geolocation_city','geolocation_state'])[['geolocation_lat','geolocation_lng']].median().reset_index()
geolocation_silver = geolocation_silver.merge(max_state,on=['geolocation_zip_code_prefix','geolocation_state'],how='inner')

# %%
customers_silver = customers_df.merge(geolocation_silver,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix',how='inner')

# %%
customers_silver.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
def plot_brazil_map(data):
    brazil = mpimg.imread(urllib.request.urlopen('https://i.pinimg.com/originals/3a/0c/e1/3a0ce18b3c842748c255bc0aa445ad41.jpg'),'jpg')
    ax = data.plot(kind="scatter", x="geolocation_lng", y="geolocation_lat", figsize=(10,10), alpha=0.3,s=0.3,c='blue')
    plt.axis('off')
    plt.imshow(brazil, extent=[-73.98283055, -33.8,-33.75116944,5.4])
    plt.show()

# %%
plot_brazil_map(customers_silver.drop_duplicates(subset='customer_unique_id'))

# %% [markdown]
# Berdasarkan analisis data geolokasi pelanggan, kota dengan jumlah pelanggan terbanyak adalah Sao Paulo (SP) dengan total 16.396 pelanggan, diikuti oleh Rio de Janeiro (RJ) dengan 7.283 pelanggan, dan Belo Horizonte (MG) dengan 2.910 pelanggan, menunjukkan bahwa platform E-Commerce ini lebih populer di daerah perkotaan yang padat penduduk, sehingga perusahaan dapat merencanakan strategi pemasaran yang lebih efektif dan efisien di kota-kota besar ini untuk meningkatkan penjualan dan kepuasan pelanggan.

# %%
customer_locations = customers_silver.groupby(['geolocation_city', 'geolocation_state']).size().reset_index(name='customer_count')


customer_locations_sorted = customer_locations.sort_values(by='customer_count', ascending=False)

top_10_customer_locations = customer_locations_sorted.head(10)

print("Top 10 Lokasi Geografis Pelanggan Terbanyak:")
print(top_10_customer_locations)
# Out:
# Top 10 Lokasi Geografis Pelanggan Terbanyak:
#            geolocation_city geolocation_state  customer_count
# 3846              sao paulo                SP           16396
# 3352         rio de janeiro                RJ            7283
# 479          belo horizonte                MG            2910
# 597                brasilia                DF            2040
# 1204               curitiba                PR            1583
# 753                campinas                SP            1522
# 3140           porto alegre                RS            1430
# 3451               salvador                BA            1351
# 1618              guarulhos                SP            1253
# 3657  sao bernardo do campo                SP            1015

# %%
import seaborn as sns

import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))
sns.barplot(x='customer_count', y='geolocation_city', data=top_10_customer_locations, palette='viridis')
plt.title('Top 10 Geographic Locations of Customers')
plt.xlabel('Number of Customers')
plt.ylabel('City')
plt.show()
# Out:
# C:\Users\AndhikaSep\AppData\Local\Temp\ipykernel_22356\1316621970.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='customer_count', y='geolocation_city', data=top_10_customer_locations, palette='viridis')

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# ## Kesimpulan
#
# 1. **Apa saja produk terlaris dan produk yang kurang diminati dalam beberapa bulan terakhir?**
#     - Produk terlaris: Kategori produk `bed_bath_table`, `health_beauty`, `sports_leisure`, dan `furniture_decor` adalah yang paling diminati oleh pelanggan.
#     - Produk yang kurang diminati: Kategori produk `security_and_services`, `fashion_childrens_clothes`, `cds_dvds_musicals`, dan `la_cuisine` menunjukkan penjualan yang rendah.
#
# 2. **Berapa banyak total pengeluaran pelanggan selama periode tertentu?**
#     - Total pengeluaran pelanggan selama periode tertentu menunjukkan fluktuasi yang signifikan. Puncak pengeluaran terjadi pada bulan November 2017, kemungkinan karena adanya promosi besar seperti Black Friday. Pengeluaran juga meningkat pada awal tahun 2018.
#
# 3. **Bagaimana perkembangan performa penjualan dari waktu ke waktu?**
#     - Performa penjualan menunjukkan tren peningkatan dari awal tahun 2017 hingga akhir tahun 2018, dengan beberapa puncak penjualan yang signifikan pada bulan-bulan tertentu. Ini menunjukkan adanya musim atau event tertentu yang mendorong peningkatan penjualan.
#
# 4. **Dimana lokasi geografis pelanggan terbanyak berada?**
#     - Lokasi geografis dengan jumlah pelanggan terbanyak adalah `sao paulo (SP)`, diikuti oleh `rio de janeiro (RJ)`, `belo horizonte (MG)`, dan `brasilia (DF)`. Ini menunjukkan bahwa sebagian besar pelanggan berasal dari kota-kota besar di Brasil, yang dapat menjadi fokus utama untuk strategi pemasaran dan distribusi produk.
